# %%
import pandas as pd
from datetime import datetime
from pathlib import Path
import csv
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
# Attack log paths
# Define relative paths
relative_attack_log_path = "data\\raw\\Modbus Dataset\\attack\\compromised-scada\\attack logs\\03-15-2023\\03-15-2023-1.csv"
relative_attack_log_path_2 = "data\\raw\\Modbus Dataset\\attack\\compromised-scada\\attack logs\\03-16-2023\\03-16-2023-1.csv"

absolute_attack_log_path = (Path("../../..") / relative_attack_log_path).resolve()
absolute_attack_path_2 = (Path("../../..") / relative_attack_log_path_2).resolve()

# Print the absolute paths
print("Absolute path to attack log data:", absolute_attack_log_path)
print("Absolute path to second attack log data:", absolute_attack_path_2)
# Out:
# Absolute path to attack log data: C:\Users\jorel\OneDrive\Documents\CODE STUFF\DOE\BNL\foundational_model_for_energy_security\data\raw\Modbus Dataset\attack\compromised-scada\attack logs\03-15-2023\03-15-2023-1.csv
# Absolute path to second attack log data: C:\Users\jorel\OneDrive\Documents\CODE STUFF\DOE\BNL\foundational_model_for_energy_security\data\raw\Modbus Dataset\attack\compromised-scada\attack logs\03-16-2023\03-16-2023-1.csv

# %%
# Processed Modbus Compromised SCADA paths
relative_modbus_compromised_scada_path = "data\\processed\\Modbus Dataset\\attack\\compromised-scada\\ied1a\\MODBUS_ONLY_veth3614724-0.csv"

absolute_modbus_compromised_scada_path = (Path("../../..") / relative_modbus_compromised_scada_path).resolve()

print("Absolute path to processed Modbus Compromised SCADA data:", absolute_modbus_compromised_scada_path)
# Out:
# Absolute path to processed Modbus Compromised SCADA data: C:\Users\jorel\OneDrive\Documents\CODE STUFF\DOE\BNL\foundational_model_for_energy_security\data\processed\Modbus Dataset\attack\compromised-scada\ied1a\MODBUS_ONLY_veth3614724-0.csv

# %%
# Load attack log data into DataFrames
attack_log_03_15_2023_df = pd.read_csv(absolute_attack_log_path)
attack_log_03_16_2023_df = pd.read_csv(absolute_attack_path_2)

print("Attack log 03-15-2023 DataFrame shape:", attack_log_03_15_2023_df.shape)
print("Attack log 03-16-2023 DataFrame shape:", attack_log_03_16_2023_df.shape)

# Combine the two attack log DataFrames
combined_attack_log_df = pd.concat([attack_log_03_15_2023_df, attack_log_03_16_2023_df], ignore_index=True)
print("Combined attack log DataFrame shape:", combined_attack_log_df.shape)

# Filter the combined attack log DataFrame for entries with TargetIP and convert Timestamp to datetime
filtered_combined_attack_log_df = combined_attack_log_df[combined_attack_log_df['TargetIP'] == '185.175.0.4'].copy()
filtered_combined_attack_log_df['datetime'] = pd.to_datetime(filtered_combined_attack_log_df['Timestamp'], utc=True)
print("Filtered combined attack log DataFrame shape:", filtered_combined_attack_log_df.shape)

display(filtered_combined_attack_log_df.head(10))
# Out:
# Attack log 03-15-2023 DataFrame shape: (101863, 4)
# Attack log 03-16-2023 DataFrame shape: (51786, 4)
# Combined attack log DataFrame shape: (153649, 4)
# Filtered combined attack log DataFrame shape: (123746, 5)
#                  Timestamp     TargetIP  \
# 0  2023-03-15 00:05:30.228  185.175.0.4
# 1  2023-03-15 00:05:30.242  185.175.0.4
# 2  2023-03-15 00:05:30.242  185.175.0.4
# 3  2023-03-15 00:05:30.243  185.175.0.4
# 4  2023-03-15 00:05:30.249  185.175.0.4
# 5   2023-03-15 00:05:30.25  185.175.0.4
# 6   2023-03-15 00:05:30.25  185.175.0.4
# 7   2023-03-15 00:05:30.25  185.175.0.4
# 8   2023-03-15 00:05:30.25  185.175.0.4
# 9   2023-03-15 00:05:30.25  185.175.0.4
#
#                                       Attack  TransactionID  \
# 0  Brute force or specific coil. Address: 13              5
# 1         Brute force or specific - Complete          65535
# 2  Brute force or specific coil. Address: 14              5
# 3         Brute force or specific - Complete          65535
# 4   Brute force or specific coil. Address: 8              5
# 5         Brute force or specific - Complete          65535
# 6                                     Replay          43473
# 7                          Replay - Complete          65535
# 8                                     Replay          43473
# 9                          Replay - Complete          65535
#
#                           datetime
# 0 2023-03-15 00:05:30.228000+00:00
# 1 2023-03-15 00:05:30.242000+00:00
# 2 2023-03-15 00:05:30.242000+00:00
# 3 2023-03-15 00:05:30.243000+00:00
# 4 2023-03-15 00:05:30.249000+00:00
# 5 2023-03-15 00:05:30.250000+00:00
# 6 2023-03-15 00:05:30.250000+00:00
# 7 2023-03-15 00:05:30.250000+00:00
# 8 2023-03-15 00:05:30.250000+00:00
# 9 2023-03-15 00:05:30.250000+00:00

# %%
# Load the processed Modbus Compromised SCADA DataFrame
modbus_comprimised_scada_df = pd.read_csv(absolute_modbus_compromised_scada_path)
print("Processed Modbus Compromised SCADA DataFrame shape:", modbus_comprimised_scada_df.shape)

# Filter the Modbus Compromised SCADA DataFrame for entries with dst_ip and src_ip
filtered_modbus_comprimised_scada_df = modbus_comprimised_scada_df[
    (modbus_comprimised_scada_df['dst_ip'] == '185.175.0.4') & 
    (modbus_comprimised_scada_df['src_ip'] == '185.175.0.3')
]

# Print the shape of the filtered Modbus Compromised SCADA DataFrame and display the first 10 rows
print("Filtered Modbus Compromised SCADA DataFrame shape:", filtered_modbus_comprimised_scada_df.shape)
display(filtered_modbus_comprimised_scada_df.head(10))
# Out:
# Processed Modbus Compromised SCADA DataFrame shape: (151443, 47)
# Filtered Modbus Compromised SCADA DataFrame shape: (101513, 47)
#     packet_number     timestamp                          datetime   protocols  \
# 0               4  1.678846e+09  2023-03-15T02:01:05.333506+00:00  Modbus/TCP
# 2              12  1.678846e+09  2023-03-15T02:01:05.394348+00:00  Modbus/TCP
# 4              24  1.678846e+09  2023-03-15T02:01:05.477443+00:00  Modbus/TCP
# 6              36  1.678846e+09  2023-03-15T02:01:05.569057+00:00  Modbus/TCP
# 8              48  1.678846e+09  2023-03-15T02:01:05.646554+00:00  Modbus/TCP
# 10             61  1.678846e+09  2023-03-15T02:01:10.677501+00:00  Modbus/TCP
# 12             72  1.678846e+09  2023-03-15T02:01:10.734234+00:00  Modbus/TCP
# 14             84  1.678846e+09  2023-03-15T02:01:10.777678+00:00  Modbus/TCP
# 16             96  1.678846e+09  2023-03-15T02:01:10.914418+00:00  Modbus/TCP
# 18            107  1.678846e+09  2023-03-15T02:01:10.946195+00:00  Modbus/TCP
#
#          src_ip       dst_ip  src_port  dst_port  tcp_len  tcp_stream  ...  \
# 0   185.175.0.3  185.175.0.4     34210       502       12           0  ...
# 2   185.175.0.3  185.175.0.4     34222       502       12           1  ...
# 4   185.175.0.3  185.175.0.4     34228       502       12           3  ...
# 6   185.175.0.3  185.175.0.4     34238       502       12           4  ...
# 8   185.175.0.3  185.175.0.4     34244       502       12           5  ...
# 10  185.175.0.3  185.175.0.4     49750       502       12           6  ...
# 12  185.175.0.3  185.175.0.4     49752       502       12           7  ...
# 14  185.175.0.3  185.175.0.4     49766       502       12           8  ...
# 16  185.175.0.3  185.175.0.4     49772       502       12           9  ...
# 18  185.175.0.3  185.175.0.4     49786       502       12          10  ...
#
#     FIN SYN  RST  PSH  ACK  URG  inter_arrival_time  time_from_start  \
# 0     0   0    0    1    1    0                 NaN         0.000000
# 2     0   0    0    1    1    0            0.020582         0.060842
# 4     0   0    0    1    1    0            0.025056         0.143937
# 6     0   0    0    1    1    0            0.020548         0.235551
# 8     0   0    0    1    1    0            0.020857         0.313048
# 10    0   0    0    1    1    0            5.004761         5.343995
# 12    0   0    0    1    1    0            0.020979         5.400728
# 14    0   0    0    1    1    0            0.030746         5.444172
# 16    0   0    0    1    1    0            0.020608         5.580912
# 18    0   0    0    1    1    0            0.020510         5.612689
#
#     requests_per_second  round_trip_time
# 0                     1         0.040260
# 2                     2         0.058039
# 4                     3         0.071066
# 6                     4         0.056640
# 8                     5         0.026186
# 10                    1         0.035754
# 12                    2         0.012698
# 14                    3         0.116132
# 16                    4         0.011267
# 18                    5         0.000940
#
# [10 rows x 47 columns]

# %%
# Filter by IP first (reduces data size)
ip_mask = (modbus_comprimised_scada_df['src_ip'] == '185.175.0.3') & \
          (modbus_comprimised_scada_df['dst_ip'] == '185.175.0.4')

# Use merge_asof for fast time-based matching
modbus_comprimised_scada_df = modbus_comprimised_scada_df.sort_values('datetime')
attack_times = filtered_combined_attack_log_df[['datetime']].sort_values('datetime')

# Find nearest attack time for each packet
merged = pd.merge_asof(
    modbus_comprimised_scada_df,
    attack_times.assign(attack_time=attack_times['datetime']),
    on='datetime',
    direction='nearest',
    tolerance=pd.Timedelta(milliseconds=100)
)

# Label based on whether a match was found AND IP matches
modbus_comprimised_scada_df['label'] = np.where(
    merged['attack_time'].notna() & ip_mask,
    'ANOMALY',
    'NORMAL'
)

# Print the shape of the Modbus Compromised SCADA DataFrame and display the first 10 rows
print("Filtered Modbus Compromised SCADA DataFrame shape:", modbus_comprimised_scada_df.shape)
display(modbus_comprimised_scada_df.head(10))
# Out:
# Filtered Modbus Compromised SCADA DataFrame shape: (151443, 48)
#    packet_number     timestamp                            datetime  \
# 0              4  1.678846e+09 2023-03-15 02:01:05.333506107+00:00
# 1              6  1.678846e+09 2023-03-15 02:01:05.373765945+00:00
# 2             12  1.678846e+09 2023-03-15 02:01:05.394347906+00:00
# 3             18  1.678846e+09 2023-03-15 02:01:05.452387094+00:00
# 4             24  1.678846e+09 2023-03-15 02:01:05.477442980+00:00
# 5             27  1.678846e+09 2023-03-15 02:01:05.548508883+00:00
# 6             36  1.678846e+09 2023-03-15 02:01:05.569056988+00:00
# 7             39  1.678846e+09 2023-03-15 02:01:05.625696898+00:00
# 8             48  1.678846e+09 2023-03-15 02:01:05.646553993+00:00
# 9             51  1.678846e+09 2023-03-15 02:01:05.672739983+00:00
#
#     protocols       src_ip       dst_ip  src_port  dst_port  tcp_len  \
# 0  Modbus/TCP  185.175.0.3  185.175.0.4     34210       502       12
# 1  Modbus/TCP  185.175.0.4  185.175.0.3       502     34210       11
# 2  Modbus/TCP  185.175.0.3  185.175.0.4     34222       502       12
# 3  Modbus/TCP  185.175.0.4  185.175.0.3       502     34222       11
# 4  Modbus/TCP  185.175.0.3  185.175.0.4     34228       502       12
# 5  Modbus/TCP  185.175.0.4  185.175.0.3       502     34228       10
# 6  Modbus/TCP  185.175.0.3  185.175.0.4     34238       502       12
# 7  Modbus/TCP  185.175.0.4  185.175.0.3       502     34238       10
# 8  Modbus/TCP  185.175.0.3  185.175.0.4     34244       502       12
# 9  Modbus/TCP  185.175.0.4  185.175.0.3       502     34244       10
#
#    tcp_stream  ...  SYN RST  PSH  ACK  URG  inter_arrival_time  \
# 0           0  ...    0   0    1    1    0                 NaN
# 1           0  ...    0   0    1    1    0            0.040260
# 2           1  ...    0   0    1    1    0            0.020582
# 3           1  ...    0   0    1    1    0            0.058039
# 4           3  ...    0   0    1    1    0            0.025056
# 5           3  ...    0   0    1    1    0            0.071066
# 6           4  ...    0   0    1    1    0            0.020548
# 7           4  ...    0   0    1    1    0            0.056640
# 8           5  ...    0   0    1    1    0            0.020857
# 9           5  ...    0   0    1    1    0            0.026186
#
#    time_from_start  requests_per_second  round_trip_time   label
# 0         0.000000                    1         0.040260  NORMAL
# 1         0.040260                    1         0.040260  NORMAL
# 2         0.060842                    2         0.058039  NORMAL
# 3         0.118881                    2         0.058039  NORMAL
# 4         0.143937                    3         0.071066  NORMAL
# 5         0.215003                    3         0.071066  NORMAL
# 6         0.235551                    4         0.056640  NORMAL
# 7         0.292191                    4         0.056640  NORMAL
# 8         0.313048                    5         0.026186  NORMAL
# 9         0.339234                    5         0.026186  NORMAL
#
# [10 rows x 48 columns]
